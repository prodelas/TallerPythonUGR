# %% [markdown]
# # Flattening the curve of COVID-19 infections.
# ![image.png](attachment:image.png)
#
# The onset of the coronavirus pandemia of COVID-19 has led to a sudden popularization of the epidemiological phrase "flattening the curve" and there are numerous lucid explanations on the Internet.
#
# # An explainer using a simple  logistic model.
#
# But here we are going to trying to explain the phenomena showing how the features of this global pandemic evolution and the efforts to slow down its spread also emerge naturally from a simple logistic model differential equation, that can serve as a spread model of any infection, as well as it serves as a very used model of the limited expansion of many population dynamics situations.

# %% [markdown]
# **By Pedro González Rodelas**
#
# Date of creation:      12/13/2020
#
# Succesive revisions:   12/13-14/2020
#
# Last version:          12/14/2020
#
#
# Using the ideas and/or source code of the following webpages, blogs, articles and books:
#
# - [Flattening the curve](https://en.wikipedia.org/wiki/Flattening_the_curve) by [Wikipedia](https://en.wikipedia.org/).
#
#
# - [Flattening the curve](https://www.tandfonline.com/doi/full/10.1080/07468342.2020.1785250), by Gary Kennedy in [The College Mathematics Journal](https://www.maa.org/press/periodicals/college-mathematics-journal/the-college-mathematics-journal) (September 2020).
#
# - [Coronavirus: What is 'flattening the curve' and will it work?](https://www.livescience.com/coronavirus-flatten-the-curve.html) by Brandon Specktor in [LIVESCIENCE](https://www.livescience.com/) (March, 2020).
#
# - [Flattening the curve is not enough, we need to squash it: An explainer using a simple model](https://www.researchgate.net/publication/340390964_Flattening_the_curve_is_not_enough_we_need_to_squash_it_An_explainer_using_a_simple_model) medRxiv preprint by E. Mcbryde, M. Meehan, J. Trauer (April 2020).
#
# - [Exponential & logistic growth](https://www.khanacademy.org/science/ap-biology/ecology-ap/population-ecology-ap/a/exponential-logistic-growth) by [Khan Academy](https://en.khanacademy.org/).
#
# - [Mathematical modelling of infectious disease](https://en.wikipedia.org/wiki/Mathematical_modelling_of_infectious_disease#The_SIR_model) by [Wikipedia](https://en.wikipedia.org/).
#
# - Source Python code listings for the book [Numerical Python - A Practical Techniques Approach for Industry (second edition)](http://www.apress.com/9781484205549) (ISBN 978-1-484205-54-9) by Robert Johansson.

# %%
# %pwd
# Out:
# 'C:\\Users\\Usuario\\Dropbox (DropBox Básico)\\Docencia\\HeLA\\Flattening_the_curve'

# %%
# %ls
# Out:
#  El volumen de la unidad C no tiene etiqueta.
#  El n£mero de serie del volumen es: 8AEE-E6FD
#
#  Directorio de C:\Users\Usuario\Dropbox (DropBox B sico)\Docencia\HeLA\Flattening_the_curve
#
# 16/12/2020  09:17    <DIR>          .
# 16/12/2020  09:17    <DIR>          ..
# 16/12/2020  09:11    <DIR>          .ipynb_checkpoints
# 13/12/2020  23:17    <DIR>          __pycache__
# 13/12/2020  03:47            35.182 ch9-direction-field (Copia en conflicto de cvihs213178.ugr.es 2020-12-15).pdf
# 13/12/2020  22:31            35.212 ch9-direction-field.pdf
# 13/12/2020  23:30            34.074 direction-field-and-approx-sol.pdf
# 13/12/2020  22:56            39.101 exp-log_growth-direction-fields.pdf
# 13/12/2020  12:07         2.455.315 Flattening_the_curve_of_COVID-19 (Copia en conflicto de cvihs213178.ugr.es 2020-12-15).ipynb
# 14/12/2020  17:50         2.996.218 Flattening_the_curve_of_COVID-19.ipynb
# 13/12/2020  12:21         2.493.936 Flattening_the_curve_of_COVID-19_first.ipynb
# ...

# %% [markdown]
# ## What is  *flattening the curve* of coronavirus?

# %% [markdown]
# The fundamental idea is the following:
#
# Many hundreds of thousands of infections will inevitably happen — but they don't all have to happen at once, and depending on its temporal evolution of infected and recovered people, it will also depend that the health systems of each country will be able to cope with the avalanche of patients who need hospitalization, or even care in an intensive care unit (ICU).

# %% [markdown]
# So, the idea of *flattening the curve* is a public health strategy to slow down the spread of the SARS-CoV-2 virus during the COVID-19 pandemic. The curve being flattened is the epidemic curve, a visual representation of the number of infected people, and those needing health care over time. During an epidemic, a health care system can break down when the number of people infected exceeds the capability of the health care system's ability to take care of them. Flattening the curve means slowing the spread of the epidemic so that the peak number of people requiring care at a time is reduced, and the health care system does not exceed its capacity. Flattening the curve relies on mitigation techniques such as social distancing.

# %% [markdown]
# A complementary measure is to increase health care capacity, to "raise the line". So "preventing a health care system from being overwhelmed requires a society to do two things:
# - 'flatten the curve'—that is, slow the rate of infection so there aren't too many cases that need hospitalization at one time—
# - and 'raise the line'—that is, boost the hospital system's capacity to treat large numbers of patients."
#
# In the case of the COVID-19 pandemic, two key measures are to increase the numbers of available ICU beds and ventilators, which are in systemic shortage.

# %% [markdown]
# The "curve" researchers are talking about refers to the projected number of people who will contract COVID-19 over a period of time (this is not a hard prediction of how many people will definitely be infected, but a theoretical number that's used to model the virus' spread.) Here's what it looks like:

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# The curve takes on different shapes, depending on the virus's infection rate. It could be a steep curve, in which the virus spreads exponentially (that is, case counts keep doubling at a consistent rate), and the total number of cases skyrockets to its peak within a few weeks. Infection curves with a steep rise also have a steep fall; after the virus infects pretty much everyone who can be infected, case numbers begin to drop exponentially, too.
#
# The faster the infection curve rises, the quicker the local health care system gets overloaded beyond its capacity to treat people. As we have seen, firstly in China and Italy, but soon afterwards all around the entire world, with more and more new patients may be forced to go without ICU beds, and more and more hospitals may run out of the basic supplies they need to respond to the outbreak.
#
# A flatter curve, on the other hand, assumes that more or less the same number of people ultimately get infected, but over a longer period of time. A slower infection rate means a less stressed health care system, fewer hospital visits on any given day and fewer sick people being turned away.

# %% [markdown]
# In the meanwhile, to the extent that the different vaccines are available and are being administered en masse to the population, essential time will have been saved to avoid the possible death of many people who are more likely to have serious complications after being infected.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# Measures such as social distancing and stay-at-home orders reduce and delay the peak of active cases, allowing more time for healthcare capacity to increase and better cope with patient load. Time gained through thus flattening the curve can be used to raise the line of healthcare capacity to better meet surging demand

# %% [markdown]
# Without pandemic containment measures—such as social distancing, vaccination, and use of face masks—pathogens can spread exponentially. This graphic illustrates how early adoption of containment measures tends to protect wider swaths of the population, thus reducing and delaying the peak of active cases.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# <img alt="" src="//upload.wikimedia.org/wikipedia/commons/thumb/8/82/Katapult_importance_social_distancing.gif/350px-Katapult_importance_social_distancing.gif" decoding="async" width="350" height="350" class="thumbimage" srcset="//upload.wikimedia.org/wikipedia/commons/thumb/8/82/Katapult_importance_social_distancing.gif/525px-Katapult_importance_social_distancing.gif 1.5x, //upload.wikimedia.org/wikipedia/commons/8/82/Katapult_importance_social_distancing.gif 2x" data-file-width="600" data-file-height="600">

# %% [markdown]
# So, this basic idea of flattening the curve is fundamental in order to really can have a control on the evolution of the epidemic spreading of the virus, without putting too many people in danger of death. At the same time it is also fundamental to increase constantly, at the same time, the slope of the capacity of the healthcare system available.

# %% [markdown]
# <img alt="" src="//upload.wikimedia.org/wikipedia/commons/thumb/e/e9/20200403_Flatten_the_curve_animated_GIF.gif/242px-20200403_Flatten_the_curve_animated_GIF.gif" decoding="async" width="484" height="272" srcset="//upload.wikimedia.org/wikipedia/commons/thumb/e/e9/20200403_Flatten_the_curve_animated_GIF.gif/363px-20200403_Flatten_the_curve_animated_GIF.gif 1.5x, //upload.wikimedia.org/wikipedia/commons/thumb/e/e9/20200403_Flatten_the_curve_animated_GIF.gif/484px-20200403_Flatten_the_curve_animated_GIF.gif 2x" data-file-width="1200" data-file-height="675">

# %% [markdown]
# But,as we can see in one of the latest graphs of the outbreak evolution for the current 10 most affected countries, many of them have not yet succeeded
#
# ![image](newplot.png)

# %% [markdown]
# In this lesson we will try to explore mathematically the impact of reducing the infection rate, and some other parameters, that can affect radically in the evolution of the pandemic expansion in any supposedly isolated population: such as that of a city, region, country or continent, although we know well that this assumption is not entirely realistic, but it would greatly complicate the analysis.
#
# On the contrary, since movements between countries and regions are currently quite restricted, with a more or less exhaustive control of travelers with PCR or antigen tests, this sort of thinking is the basis for making a prediction about the rate of spread of COVID-19 in one country by examining how it has spread in another one, with similar epidemiological characteristics.

# %% [markdown]
# In the particular case below, we can see clearly the effect of flattening the curve of infected people (the brown one), when we decrease ostensibly the number of susceptible population (in blue) and increase the number of recovered ones (greeen), depending on the values of the two parameters of a simple SIR model, one of the classical models in the [Mathematical modelling of infectious disease](https://en.wikipedia.org/wiki/Mathematical_modelling_of_infectious_disease#The_SIR_model).

# %% [markdown]
# <img alt="" src="//upload.wikimedia.org/wikipedia/commons/thumb/2/20/SIR_model_anim.gif/330px-SIR_model_anim.gif" decoding="async" width="330" height="260" class="thumbimage" srcset="//upload.wikimedia.org/wikipedia/commons/thumb/2/20/SIR_model_anim.gif/495px-SIR_model_anim.gif 1.5x, //upload.wikimedia.org/wikipedia/commons/thumb/2/20/SIR_model_anim.gif/660px-SIR_model_anim.gif 2x" data-file-width="1048" data-file-height="827">

# %% [markdown]
# #  Exponential and  logistic models of growth

# %% [markdown]
# Models in ecology and virology use a variety of mathematical methods and assumptions to model population dynamics (how populations change in size and composition over time). Some of these models represent growth without environmental constraints, while others include "ceilings" determined by limited resources, or just restrictive measures taken on purpose, such as in the event of a pandemic situation. So, mathematical models of population dynamics can be used to accurately describe changes occurring in a population and, importantly, to predict future changes.

# %% [markdown]
# ## Modeling population growth rates

# %% [markdown]
# To understand the different models that are used to represent population/pandemic dynamics, let's start by looking at a general equation for the population growth rate (change in number of individuals in a population or state of infection over time):
#
# $$\dfrac{dN}{dt} = rN$$
#
# where we denote $N\equiv N(t)$ a function that obviously depends on the time passed, that initially it will have a concrete value, denoted by $N_0 = N(0)$.

# %% [markdown]
# In this equation, $dN/dt$ is the growth rate of the (infected) population in a given instant, $N\equiv P$ is population size or just number of infected people, $t$ is time, and $r\$ is the per capita rate of increase –that is, how quickly the (infected) population grows per individual already (infected) in the population.

# %% [markdown]
# If we assume no movement of individuals into or out of the population (assuming we are treating with an isolated sample of it), $r$ is just a function rate of birth and death (or infected and recovered in case of a pandemic spreading).
#
# The equation above is very general, and we can make more specific forms of it to describe two different kinds of growth models: exponential and logistic.
#
# When the per capita rate of increase ($r$) takes the same positive value ($r_{max}>0$) regardless of the population size, then we get an **exponential growth**.
#
# When the per capita rate of increase ($r$) decreases as the population increases towards a maximum limit ($K>0$), then we get the so/called **logistic growth**.
#
# Here's a sneak preview – don't worry if you don't understand all of it yet. We'll explore exponential growth and logistic growth in more detail below.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ### Exponential growth

# %% [markdown]
# Bacteria grown in the lab provide an excellent example of exponential growth. In exponential growth, the population’s growth rate increases over time, in proportion to the size of the population.
# Let’s take a look at how this works. Bacteria reproduce by binary fission (splitting in half), and the time between divisions is about an hour for many bacterial species. To see how this exponential growth, let's start by placing 100010001000 bacteria in a flask with an unlimited supply of nutrients.
# After 111 hour: Each bacterium will divide, yielding 200020002000 bacteria (an increase of 100010001000 bacteria).
# After 222 hours: Each of the 200020002000 bacteria will divide, producing 400040004000 (an increase of 200020002000 bacteria).
# After 333 hours: Each of the 400040004000 bacteria will divide, producing 800080008000 (an increase of 400040004000 bacteria).
# The key concept of exponential growth is that the population growth rate —the number of organisms added in each generation—increases as the population gets larger. And the results can be dramatic: after 111 day (242424 cycles of division), our bacterial population would have grown from 100010001000 to over 161616 billion! When population size, $N$, is plotted over time, a J-shaped growth curve is made, as shown above.

# %% [markdown]
# How do we model the exponential growth of a population? As we mentioned briefly above, we get exponential growth when $r$ (the per capita rate of increase) for our population is positive and constant. While any positive, constant $r$ can lead to exponential growth, you will often see exponential growth represented with an $r$ of $r_{max}$, where this is the maximum per capita rate of increase for a particular species under ideal conditions, and it varies from species to species (or virus infection). For instance, bacteria can reproduce much faster than humans, and would have a higher maximum per capita rate of increase. The maximum population growth rate for a species, sometimes called its biotic potential, is expressed in the following equation:
#
# $$\dfrac{dN}{dt} = r_{max}N$$

# %% [markdown]
# ### Logistic growth

# %% [markdown]
# Exponential growth is not a very sustainable state of affairs, since it depends on infinite amounts of resources (which tend not to exist in the real world) nor the pandemic conditions may have ideal conditions all the time.
#
# So, Exponential growth may often happen for a while, if there are few individuals (infected) and many resources (or good conditions for the infection's spreading). But when the number of individuals (infected)
# gets large enough, resources start to get used up (or the spreading conditions begin to be worse), slowing the growth rate.
#
# Eventually, the growth rate will plateau, or level off, making an S-shaped curve. The population size at which it levels off, which represents the maximum population size a particular environment can support, is called the carrying capacity, denoted by $K$.

# %% [markdown]
# We can mathematically model logistic growth by modifying our equation for exponential growth, using an $r$ (per capita growth rate) that depends on population size ($N$) and how close it is to carrying capacity ($K$). Assuming that the population has a base growth rate of $r_{max}$ when it is very small, we can write the following equation:
#
# $$\dfrac{dN}{dt} = r_{max}\dfrac{(K-N)}{K}N$$
#
#
# Let's take a minute to dissect this equation and see why it makes sense. At any given point in time during a population's growth, the expression $K - N$, tells us how many more individuals can be added to the population before it hits carrying capacity.
# $(K - N)/K$ then, is the fraction of the carrying capacity that has not yet been “used up.” The more carrying capacity that has been taken, the more the $(K - N)/K$  term will reduce the growth rate.
#
# When the population is tiny, $N$ is very small compared to $K$. The $(K - N)/K$  term becomes approximately $(K/K)$, or $1$, giving us back the exponential equation. This fits with our graph above: the population grows near-exponentially at first, but levels off more and more as it approaches $K$.

# %% [markdown]
# **What factors determine carrying capacity?**
#
# Basically, any kind of resource important to a species’ survival can act as a limit. For plants, the water, sunlight, nutrients, and the space to grow are some key resources. For animals, important resources include food, water, shelter, and nesting space. Limited quantities of these resources results in competition between members of the same population, or intraspecific competition (intra- = within; -specific = species).
#
# Intraspecific competition for resources may not affect populations that are well below their carrying capacity—resources are plentiful and all individuals can obtain what they need. However, as population size increases, the competition intensifies. In addition, the accumulation of waste products can reduce an environment’s carrying capacity.
#
# When it comes to the spread of a certain infection, the increase in people affected at first notably increases the speed of the epidemic's spread, but as more people have already been infected, hospitalized/died, or have managed to cure themselves and acquire immunity, expansion will also be reduced, to the point of the so-called "herd immunity."

# %% [markdown]
# **Examples of logistic growth**
#
# Yeast, a microscopic fungus used to make bread and alcoholic beverages, can produce a classic S-shaped curve when grown in a test tube. In the graph shown below, yeast growth levels off as the population hits the limit of the available nutrients. (If we followed the population for longer, it would likely crash, since the test tube is a closed system – meaning that fuel sources would eventually run out and wastes might reach toxic levels).
#
#
# In the real world, there are variations on the “ideal” logistic curve.
#
# As shown in the graph above (Image credit: "Environmental limits to population growth" by OpenStax College, Biology, CC BY 4.0.), population size may bounce around a bit when it gets to carrying capacity, dipping below or jumping above this value. It’s common for real populations to oscillate (bounce back and forth) continually around carrying capacity, rather than forming a perfectly flat line.

# %% [markdown]
# ![image.png](logistic_growth.png)

# %% [markdown]
# **Summary**
#
# Exponential growth takes place when a population's per capita growth rate stays the same, regardless of population size, making the population grow faster and faster as it gets larger. It's represented by the equation:
#
# $$\dfrac{dN}{dt} = r_{max}N$$
#
# Logistic growth takes place when a population's per capita growth rate decreases as population size approaches a maximum imposed by limited resources, the carrying capacity($K$). It's represented by the equation:
#
# $$\dfrac{dN}{dt} = r_{max}\dfrac{(K-N)}{K}N $$
#
# - Exponential growth produces a J-shaped curve.
# - Logistic growth produces an S-shaped curve.

# %% [markdown]
# # Analytical manual resolution

# %% [markdown]
# In the **Exponential growth** case we have to solve a differential equation like this:
#
# $$\dfrac{dN}{dt} = r N$$
#
# that can be rewritten as a differential equation of separate variables in this form:
#
# $$\dfrac{dN}{N} = r dt $$
#
# and taking the corresponding integral on both sides of the equality, except for the additive constant $C$, we would have:
#
# $$log(N) = r t + C$$
#
# that can be rewritten, taking the exponential on both sides, as:
#
# $$N\equiv N(t) = e^{(r t + C)}=e^C\, e^{r t}\equiv C_1\,e^{r t} $$

# %% [markdown]
# In the **Logistic growth** case we can proceed in a similar way to solve the equation:
#
# $$\dfrac{dN}{dt} = r\dfrac{(K-N)}{K}N $$
#
# firstly writing it as a differential equation of separate variables:
#
# $$\dfrac{dN}{(K-N)N} = \dfrac{ r}{K} dt $$
#
# but now, before integrating on both sides of the equality, we will have to decompose into simple fractions the rational function of $N$ on the left hand side
#
# $$\dfrac{1}{(K-N)N} = \dfrac{A}{K-N}+\dfrac{B}{N}= \dfrac{A\,N+B\,(K-N)}{(K-N)N}= \dfrac{\dfrac{1}{K}}{K-N}+\dfrac{\dfrac{1}{K}}{N}$$

# %% [markdown]
# and now, taken the integrals:
#
# $$\dfrac{1}{K}\left(log(N)-log(N-K)\right)=\dfrac{1}{K}\,log(\dfrac{N}{N-K}) = \dfrac{ r}{K} t + C$$
#
# and cancelling the $K$ denominator on both sides and taking the exponential, as before:
#
# $$\dfrac{N}{N-K} = C_1\,e^{r t} $$
#
# which leads to the following general solution of this differential equation:
#
# $$N\equiv N(t) = -\dfrac{K\, C_1\,e^{r t} }{1-C_1\,e^{r t}}$$
#
# still depending on the two parameters $r$ and $K$ and on the integration constant $C_1$ that finally will be calculated from the corresponding initial condition  $N(0)=N_0\in\mathbb{R}^{+}_0$ (see the symbolic computation below).

# %% [markdown]
# # Python Implementation

# %%
import numpy as np

# %%
# %matplotlib inline
# %config InlineBackend.figure_format='retina'
import matplotlib.pyplot as plt
import matplotlib as mpl
# mpl.rcParams['text.usetex'] = True
mpl.rcParams['mathtext.fontset'] = 'stix'
mpl.rcParams['font.family'] = 'serif'
mpl.rcParams['font.sans-serif'] = 'stix'

# %%
import sympy
# sympy.init_printing()

# %%
from scipy import integrate

# %% [markdown]
# ## Symbolic ODE solving with SymPy

# %%
t, r, K, N0, = sympy.symbols("t, r, K, N_0")

# %%
N = sympy.Function("N")

# %%
# ?sympy.dsolve

# %% [markdown]
# ### Exponential growth

# %%
ode = N(t).diff(t) - r*N(t)

# %%
ode
# Out:
# -r*N(t) + Derivative(N(t), t)

# %%
ode_sol = sympy.dsolve(ode)

# %%
ode_sol
# Out:
# Eq(N(t), C1*exp(r*t))

# %%
ode_sol.lhs
# Out:
# N(t)

# %%
ode_sol.rhs
# Out:
# C1*exp(r*t)

# %%
ics = {N(0): N0}

# %%
ics
# Out:
# {N(0): N_0}

# %%
C_eq = ode_sol.subs(t, 0).subs(ics)

# %%
C_eq
# Out:
# Eq(N_0, C1)

# %%
C_sol = sympy.solve(C_eq)

# %%
C_sol
# Out:
# [{C1: N_0}]

# %%
ode_sol.subs(C_sol[0])
# Out:
# Eq(N(t), N_0*exp(r*t))

# %%
ode_sol_expgrowth = ode_sol.subs(C_sol[0])

# %%
ode_sol_expgrowth
# Out:
# Eq(N(t), N_0*exp(r*t))

# %% [markdown]
# ### Logistic growth

# %%
ode = N(t).diff(t) - r*N(t)*(K-N(t))/K

# %%
ode
# Out:
# Derivative(N(t), t) - r*(K - N(t))*N(t)/K

# %%
ode_sol = sympy.dsolve(ode,ics = ics)

# %%
ode_sol
# Out:
# Eq(N(t), -K*N_0*exp(r*t)/((K - N_0)*(-N_0*exp(r*t)/(K - N_0) - 1)))

# %%
ode_sol.rhs
# Out:
# -K*N_0*exp(r*t)/((K - N_0)*(-N_0*exp(r*t)/(K - N_0) - 1))

# %%
ode_sol_loggrowth = ode_sol

# %% [markdown]
# ## Graphical behavior of solutions

# %%
ode_sol_expgrowth
# Out:
# Eq(N(t), N_0*exp(r*t))

# %%
ode_sol_loggrowth
# Out:
# Eq(N(t), -K*N_0*exp(r*t)/((K - N_0)*(-N_0*exp(r*t)/(K - N_0) - 1)))

# %%
r, K = sympy.symbols('r,K')
yexpgrowth_x = sympy.lambdify((t,r), ode_sol_expgrowth.rhs.subs({N0:0.02}), 'numpy')

# %%
yexpgrowth_x(0,r=1)
# Out:
# 0.02

# %%
yloggrowth_x = sympy.lambdify((t,r,K), ode_sol_loggrowth.rhs.subs({N0:0.02}), 'numpy')

# %%
yloggrowth_x(0,r=1, K =5)
# Out:
# 0.019999999999999997

# %%
fig, ax = plt.subplots(figsize=(8, 4))

x = np.linspace(0, 4, 100)

for r in [1, 1.5, 2.]:
    ax.plot(x, yexpgrowth_x(x, r), label=r"$r=%f$" % r)

ax.set_title(r"$%s$" % sympy.latex(ode_sol_expgrowth), fontsize=18)
ax.set_xlabel(r"$x$", fontsize=18)
ax.set_ylabel(r"$y$", fontsize=18)
ax.legend()

fig.tight_layout()

# %%
fig, ax = plt.subplots(figsize=(8, 4))

x = np.linspace(0, 10, 100)

for K in [1, 2, 5]:
    ax.plot(x, yloggrowth_x(x,1,K), label=r"$K=%d$" % K)

ax.set_title(r"$%s$" % sympy.latex(ode_sol_loggrowth), fontsize=18)
ax.set_xlabel(r"$x$", fontsize=18)
ax.set_ylabel(r"$y$", fontsize=18)
ax.legend()

fig.tight_layout()

# %% [markdown]
# ### Direction fields

# %%
def  plot_direction_field(x, y_x, f_xy, x_lim=(0, 5), y_lim=(0, 5), ax=None):
    
    f_np = sympy.lambdify((x, y_x), f_xy, 'numpy')
    
    x_vec = np.linspace(x_lim[0], x_lim[1], 20)
    y_vec = np.linspace(y_lim[0], y_lim[1], 20)
    
    if ax is None:
        _, ax = plt.subplots(figsize=(4, 4))

    dx = x_vec[1] - x_vec[0]
    dy = y_vec[1] - y_vec[0]

    for m, xx in enumerate(x_vec):
        for n, yy in enumerate(y_vec):
            Dy = f_np(xx, yy) * dx
            Dx = 0.8 * dx**2 / np.sqrt(dx**2 + Dy**2)
            Dy = 0.8 * Dy*dy / np.sqrt(dx**2 + Dy**2)
            ax.plot([xx - Dx/2, xx + Dx/2],
                    [yy - Dy/2, yy + Dy/2], 'b', lw=0.5)
    ax.axis('tight')

    ax.set_title(r"$%s$" %
                 (sympy.latex(sympy.Eq(y(x).diff(x), f_xy))),
                 fontsize=18)
    
    return ax

# %%
x = sympy.symbols("x")

# %%
y = sympy.Function("y")

# %%
fig, axes = plt.subplots(2, 2, figsize=(12, 12))
r = 1; K = 1;
plot_direction_field(x, y(x), r*y(x), ax=axes[0,0])
plot_direction_field(x, y(x), r*y(x)*(K-y(x))/K, ax=axes[0,1])
# plot_direction_field(x, y(x), y(x)**2 / x, ax=axes[2])
r = 2; K = 5;
plot_direction_field(x, y(x), r*y(x), ax=axes[1,0])
plot_direction_field(x, y(x), r*y(x)*(K-y(x))/K, ax=axes[1,1])

fig.tight_layout()
fig.savefig('exp-log_growth-direction-fields.pdf')

# %% [markdown]
# ### Systematic solutions of ODEs

# %%
x = sympy.symbols("x")

# %%
y = sympy.Function("y")

# %%
f_exp = r*y(x)
f_log = r*y(x)*(K-y(x))/K
#f = y(x)**2 + x
#f = sympy.cos(y(x)**2) + x
#f = sympy.sqrt(y(x)) * sympy.cos(x**2)
#f = y(x)**2 / x

# %%
f = f_exp
sympy.Eq(y(x).diff(x), f)
# Out:
# Eq(Derivative(y(x), x), 2*y(x))

# %%
ics = {y(0): 0.02}

# %%
ode_sol_exp = sympy.dsolve(y(x).diff(x) - f)

# %%
ode_sol = ode_sol_exp

# %%
ode_sol
# Out:
# Eq(y(x), C1*exp(2*x))

# %%
ode_sol_exp_minus = sympy.dsolve(y(x).diff(x) + f)

# %%
ode_sol_exp_minus
# Out:
# Eq(y(x), C1*exp(-2*x))

# %% [markdown]
# #### Function for applying initial conditions

# %%
def apply_ics(sol, ics, x, known_params):
    """
    Apply the initial conditions (ics), given as a dictionary on
    the form ics = {y(0): y0: y(x).diff(x).subs(x, 0): yp0, ...}
    to the solution of the ODE with indepdendent variable x.
    The undetermined integration constants C1, C2, ... are extracted
    from the free symbols of the ODE solution, excluding symbols in
    the known_params list.
    """
    free_params = sol.free_symbols - set(known_params)
    eqs = [(sol.lhs.diff(x, n) - sol.rhs.diff(x, n)).subs(x, 0).subs(ics)
           for n in range(len(ics))]
    sol_params = sympy.solve(eqs, free_params)
    return sol.subs(sol_params)

# %%
ode_sol = ode_sol_exp
ode_sol_exp = apply_ics(ode_sol, ics, x, [])

# %%
ode_sol = ode_sol_exp_minus;  ics = {y(0): 10.} 
ode_sol_exp_minus = apply_ics(ode_sol, ics, x, [])

# %%
ode_sol_exp
# Out:
# Eq(y(x), 0.02*exp(2*x))

# %%
ode_sol_exp_minus
# Out:
# Eq(y(x), 10.0*exp(-2*x))

# %%
f = f_log;
ode_sol_log = sympy.dsolve(y(x).diff(x) - f, ics=ics)

# %%
ics = {y(0): 4.98} 
ode_sol_log_minus = sympy.dsolve(y(x).diff(x) + f, ics=ics)

# %%
ode_sol_log
# Out:
# Eq(y(x), 5/(1 - 0.5*exp(-2*x)))

# %%
ode_sol_log_minus
# Out:
# Eq(y(x), -1245.0/(-exp(2*x) - 249.0))

# %%
fig, axes = plt.subplots(1, 2, figsize=(8, 4))

ode_sol = ode_sol_exp; ics = {y(0): 0.02}
plot_direction_field(x, y(x), f_exp, ax=axes[0])
x_vec = np.linspace(0, 5, 100)
axes[0].plot(x_vec, sympy.lambdify(x, ode_sol.rhs.removeO())(x_vec), 'r', lw=2)
axes[1].set_ylim(0, 5)

ode_sol = ode_sol_log; ics = {y(0): 0.02}
plot_direction_field(x, y(x), f_log, ax=axes[1])
x_vec = np.linspace(0, 5, 100)
axes[1].plot(x_vec, sympy.lambdify(x, ode_sol.rhs.removeO())(x_vec), 'b', lw=2)
axes[1].set_ylim(0, 5)

dx = 0.125

for x0 in np.arange(0, 1., dx):
    x_vec = np.linspace(x0, x0 + dx, 100)
    ics = {y(x0): ode_sol.rhs.removeO().subs(x, x0)}
    ode_sol_p = sympy.dsolve(y(x).diff(x) - f_log, ics=ics, n=6)
    axes[1].plot(x_vec, sympy.lambdify(x, ode_sol_p.rhs.removeO())(x_vec), 'r', lw=2)
    

    
fig.tight_layout()
fig.savefig("direction-field-and-approx-sol.pdf")

# %%
fig, axes = plt.subplots(1, 2, figsize=(8, 4))

ode_sol = ode_sol_exp; ics = {y(0): 0.02}
plot_direction_field(x, y(x), f_exp, ax=axes[0])
x_vec = np.linspace(0, 5, 100)
axes[0].plot(x_vec, sympy.lambdify(x, ode_sol.rhs.removeO())(x_vec), 'r', lw=2)
axes[0].set_ylim(0, 5)

ode_sol = ode_sol_exp_minus; ics = {y(0): 10.}
plot_direction_field(x, y(x), -f_exp, ax=axes[1])
x_vec = np.linspace(0, 5, 100)
axes[1].plot(x_vec, sympy.lambdify(x, ode_sol.rhs.removeO())(x_vec), 'b', lw=2)
axes[1].set_ylim(0, 5)


dx = 0.125


    
fig.tight_layout()
fig.savefig("direction-field-and-approx-sol-exp.pdf")

# %%
fig, axes = plt.subplots(1, 2, figsize=(8, 4))

ode_sol = ode_sol_log; ics = {y(0): 0.02}
plot_direction_field(x, y(x), f_log, ax=axes[0])
x_vec = np.linspace(0, 5, 100)
axes[0].plot(x_vec, sympy.lambdify(x, ode_sol.rhs.removeO())(x_vec), 'b', lw=2)
axes[0].set_ylim(0, 5)

ode_sol = ode_sol_log_minus; ics = {y(0): 4.98}
plot_direction_field(x, y(x), -f_log, ax=axes[1])
x_vec = np.linspace(0, 5, 100)
axes[1].plot(x_vec, sympy.lambdify(x, ode_sol.rhs.removeO())(x_vec), 'b', lw=2)
axes[1].set_ylim(0, 5)

dx = 0.125

for x0 in np.arange(0, 1., dx):
    x_vec = np.linspace(x0, x0 + dx, 100)
    ics = {y(x0): ode_sol.rhs.removeO().subs(x, x0)}
    ode_sol_p = sympy.dsolve(y(x).diff(x) - f_log, ics=ics, n=6)
    axes[1].plot(x_vec, sympy.lambdify(x, ode_sol_p.rhs.removeO())(x_vec), 'r', lw=2)
    

    
fig.tight_layout()
fig.savefig("direction-field-and-approx-sol.pdf")

# %%
fig, axes = plt.subplots(2, 2, figsize=(8, 4))

ode_sol = ode_sol_exp; ics = {y(0): 0.02}
plot_direction_field(x, y(x), f_exp, ax=axes[0,0])
x_vec = np.linspace(0, 5, 100)
axes[0,0].plot(x_vec, sympy.lambdify(x, ode_sol.rhs.removeO())(x_vec), 'r', lw=2)
axes[0,0].set_ylim(0, 5)

ode_sol = ode_sol_exp; ics = {y(0): 0.02}
plot_direction_field(x, y(x), -f_exp, ax=axes[0,1])
x_vec = np.linspace(0, 5, 100)
axes[0,1].plot(x_vec, sympy.lambdify(x, ode_sol.rhs.removeO())(x_vec), 'r', lw=2)
axes[0,1].set_ylim(0, 5)

ode_sol = ode_sol_log; ics = {y(0): 0.02}
plot_direction_field(x, y(x), f_log, ax=axes[1,0])
x_vec = np.linspace(0, 5, 100)
axes[1,0].plot(x_vec, sympy.lambdify(x, ode_sol.rhs.removeO())(x_vec), 'b', lw=2)
axes[1,0].set_ylim(0, 5)

ode_sol = ode_sol_log_minus; ics = {y(0): 0.02}
plot_direction_field(x, y(x), -f_log, ax=axes[1,1])
x_vec = np.linspace(0, 5, 100)
axes[1,1].plot(x_vec, sympy.lambdify(x, ode_sol.rhs.removeO())(x_vec), 'b', lw=2)
axes[1,1].set_ylim(0, 5)

dx = 0.125

for x0 in np.arange(0, 1., dx):
    x_vec = np.linspace(x0, x0 + dx, 100)
    ics = {y(x0): ode_sol.rhs.removeO().subs(x, x0)}
    ode_sol_p = sympy.dsolve(y(x).diff(x) - f_log, ics=ics, n=6)
    axes[1,1].plot(x_vec, sympy.lambdify(x, ode_sol_p.rhs.removeO())(x_vec), 'r', lw=2)
    

    
fig.tight_layout()
fig.savefig("direction-field-and-approx-sol-log.pdf")

# %% [markdown]
# As we can see clearly, both in the direction fields and graphs of particular solutions of both the exponential and logistic growth equations, at the beginning they behave in a similar way (red zone in the logistic case), but very soon the differences appear.

# %% [markdown]
# ## Numerical integration of ODEs using SciPy

# %%
x = sympy.symbols("x")

# %%
y = sympy.Function("y")

# %%
f = f_log

# %%
f_np_exp = sympy.lambdify((y(x), x), f_exp, 'math')
f_np_log = sympy.lambdify((y(x), x), f_log, 'math')

# %%
y0 = 0.02

# %%
xp = np.linspace(0, 5, 100)

# %%
xp.shape
# Out:
# (100,)

# %%
yp_exp = integrate.odeint(f_np_exp, y0, xp)
yp_log = integrate.odeint(f_np_log, y0, xp)

# %%
xm = np.linspace(0, 1, 100)

# %%
ym_exp = integrate.odeint(f_np_exp, y0, xm)
ym_log = integrate.odeint(f_np_log, y0, xm)

# %%
fig, ax = plt.subplots(1, 2, figsize=(16, 8))
plot_direction_field(x, y(x), f_exp, ax=ax[0])
plot_direction_field(x, y(x), f_log, ax=ax[1])

ax[0].plot(xp, yp_exp, 'b', lw=2)
ax[0].plot(xm, ym_exp, 'r', lw=2)

ax[1].plot(xp, yp_log, 'b', lw=2)
ax[1].plot(xm, ym_log, 'r', lw=2)

fig.savefig('odeint-logistic_eq.pdf')

# %% [markdown]
# ## Versions

# %%
# %reload_ext version_information

# %%
# %version_information numpy, scipy, sympy, matplotlib
# Out:
# Software versions
# Python 3.7.6 64bit [MSC v.1916 64 bit (AMD64)]
# IPython 7.12.0
# OS Windows 10 10.0.18362 SP0
# numpy 1.18.1
# scipy 1.4.1
# sympy 1.5.1
# matplotlib 3.1.3
# Wed Dec 16 09:18:41 2020 Hora estándar romance
